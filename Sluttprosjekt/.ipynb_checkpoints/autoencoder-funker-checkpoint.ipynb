# %%
import tensorflow as tf
import numpy as np
import os
import skimage

# %%
path = "croppedImages/"

num = 8000 #ca 8 000 in folder

dataset = []

for img in range(1,num + 1): 
    img_array = skimage.util.img_as_float32(skimage.io.imread(path + str(img) + ".png"))
    dataset.append(img_array.flatten())

print(len(dataset))
# Out:
# 5000

# %%
import random

random.shuffle(dataset)

training = np.array(dataset [0:int(num*0.8)])
testing = np.array(dataset [int(num*0.8):])

print(training.shape)
print(testing.shape)
# Out:
# (4000, 49152)
# (1000, 49152)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

model.add(Dense(64*64*3, input_dim=dataset.shape[1], activation='relu'))
model.add(Dense(16*16*3, activation='relu'))
model.add(Dense(64*64*3, activation='relu'))
model.add(Dense(training.shape[1])) # Multiple output neurons
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(dataset,dataset,batch_size = 64, verbose=1,epochs=10)
# Out:
# WARNING:tensorflow:From C:\Users\Jim-Alexander\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\Jim-Alexander\Anaconda3\lib\site-packages\tensorflow\python\keras\utils\losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From C:\Users\Jim-Alexander\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
# 4000/4000 [==============================] - 9s 2ms/sample - loss: 0.1209
# Epoch 2/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0432
# Epoch 3/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0421
# Epoch 4/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0413
# Epoch 5/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0372
# Epoch 6/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0366
# Epoch 7/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0340
# Epoch 8/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0338
# Epoch 9/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0337
# Epoch 10/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0338
# Epoch 11/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0337
# Epoch 12/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0337
# Epoch 13/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0337
# Epoch 14/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0337
# Epoch 15/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0337
# Epoch 16/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0338
# Epoch 17/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0343
# Epoch 18/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0338
# Epoch 19/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0338
# Epoch 20/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0337
# Epoch 21/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0337
# Epoch 22/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0336
# Epoch 23/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0339
# Epoch 24/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0347
# Epoch 25/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0336
# Epoch 26/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0337
# Epoch 27/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0337
# Epoch 28/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0337
# Epoch 29/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0339
# Epoch 30/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0354
# Epoch 31/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0337
# Epoch 32/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0336
# Epoch 33/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0337
# Epoch 34/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0337
# Epoch 35/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0337
# Epoch 36/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0336
# Epoch 37/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0337
# Epoch 38/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0339
# Epoch 39/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0338
# Epoch 40/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0341
# Epoch 41/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0339
# Epoch 42/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0337
# Epoch 43/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0336
# Epoch 44/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0341
# Epoch 45/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0346
# Epoch 46/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0338
# Epoch 47/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0337
# Epoch 48/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0336
# Epoch 49/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0338
# Epoch 50/50
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 0.0338

# %%
print("Score neural network")
pred = model.predict(testing)

cols,rows = 128,128
for i in range(3):
    predicted = pred[i].reshape(rows,cols,3)
    original = testing[i].reshape(rows,cols,3)   
    
    skimage.io.imshow_collection([original,predicted])
    skimage.io.show()
# Out:
# Score neural network

# %%
from tensorflow.python.client import device_lib

device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 2406026294477704550, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 3154483609
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 13563915552571730373
#  physical_device_desc: "device: 0, name: GeForce GTX 970, pci bus id: 0000:01:00.0, compute capability: 5.2"]
